# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Define o caminho base no seu Drive
base_path = '/content/drive/MyDrive/E-commerce_Insight_Pipeline'

folders = [
    f'{base_path}/scripts',
    f'{base_path}/data',
    f'{base_path}/dbt_ecommerce',
    f'{base_path}/dbt_ecommerce/models'
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Pasta criada: {folder}")
# Out:
# Pasta criada: /content/drive/MyDrive/E-commerce_Insight_Pipeline/scripts
# Pasta criada: /content/drive/MyDrive/E-commerce_Insight_Pipeline/data
# Pasta criada: /content/drive/MyDrive/E-commerce_Insight_Pipeline/dbt_ecommerce
# Pasta criada: /content/drive/MyDrive/E-commerce_Insight_Pipeline/dbt_ecommerce/models

# %%
# Ferramentas para Scraping, Banco de Dados e Transformação
# !pip install requests beautifulsoup4 duckdb pandas dbt-duckdb
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: dbt-duckdb in /usr/local/lib/python3.12/dist-packages (1.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: dbt-common<2,>=1 in /usr/local/lib/python3.12/dist-packages (from dbt-duckdb) (1.37.3)
# Requirement already satisfied: dbt-adapters<2,>=1 in /usr/local/lib/python3.12/dist-packages (from dbt-duckdb) (1.22.9)
# Requirement already satisfied: dbt-core>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-duckdb) (1.11.7)
# Requirement already satisfied: agate<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2,>=1->dbt-duckdb) (1.9.1)
# Requirement already satisfied: dbt-protos<2.0,>=1.0.291 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2,>=1->dbt-duckdb) (1.0.443)
# Requirement already satisfied: mashumaro<3.15,>=3.9 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2,>=1->dbt-duckdb) (3.14)
# Requirement already satisfied: protobuf<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-adapters<2,>=1->dbt-duckdb) (6.33.6)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2,>=1->dbt-duckdb) (0.4.6)
# Requirement already satisfied: deepdiff<9.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2,>=1->dbt-duckdb) (8.6.2)
# Requirement already satisfied: isodate<0.8,>=0.6 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2,>=1->dbt-duckdb) (0.7.2)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2,>=1->dbt-duckdb) (3.1.6)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2,>=1->dbt-duckdb) (4.26.0)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /usr/local/lib/python3.12/dist-packages (from dbt-common<2,>=1->dbt-duckdb) (0.12.1)
# Requirement already satisfied: click<9.0,>=8.3.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (8.3.1)
# Requirement already satisfied: daff>=1.3.46 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (1.4.2)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.6.0)
# Requirement already satisfied: dbt-semantic-interfaces<0.10,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.9.0)
# Requirement already satisfied: networkx<4.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (3.6.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (26.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (2.12.3)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (6.0.3)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (1.1.0)
# Requirement already satisfied: sqlparse<0.5.5,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.5.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: Babel>=2.0 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (2.18.0)
# Requirement already satisfied: leather>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (0.4.1)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (1.1.8)
# Requirement already satisfied: importlib-metadata<9,>=6.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-duckdb) (8.7.1)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-duckdb) (10.8.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from deepdiff<9.0,>=7.0->dbt-common<2,>=1->dbt-duckdb) (5.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4,>=3.1.3->dbt-common<2,>=1->dbt-duckdb) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (0.30.0)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2,>=1->dbt-duckdb) (1.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-duckdb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-duckdb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->dbt-core>=1.8.0->dbt-duckdb) (0.4.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9,>=6.0->dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.8.0->dbt-duckdb) (3.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (1.3)
